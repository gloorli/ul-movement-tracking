# %% [markdown]
# # LOOCV classification performance evaluation
# Notebook to evaluate the tracking performance of functional arm movements using GMAC thresholds derived from the optimized threshold model in comparison with conventional GMAC thresholds.
# Tracking performance is evaluated over all and per task.

# %%
from functions.classification_performance_LOOCV import *
from utilities import *

# %%
initial_path = '../data/CreateStudy'
s_json_files = get_json_paths(initial_path, 'S')

# %%
LOOCV_test = LOOCV_performance(s_json_files)

# %%
LOOCV_test.LOOCV_complete()
# Out:
# Validation on participant  S001
# Polynomial Predictions of personal COUNT threshold:  [169.59668233] . Ground truth individual optimal threshold NDH:  199.0
# Polynomial Predictions of personal ELEVATION threshold:  [33.05480662] . Ground truth individual optimal threshold NDH:  57.6
# AUC: 0.4890724946695096
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 97.65832889835019%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.470682302771855
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 93.98616285258116%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# Validation on participant  S008
# Polynomial Predictions of personal COUNT threshold:  [131.28273241] . Ground truth individual optimal threshold NDH:  98.0
# Polynomial Predictions of personal ELEVATION threshold:  [39.15798214] . Ground truth individual optimal threshold NDH:  20.0
# AUC: 0.5944339499739448
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 62.48093543467209%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6860778183081466
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 54.60091509913574%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S009
# Polynomial Predictions of personal COUNT threshold:  [52.2507314] . Ground truth individual optimal threshold NDH:  59.2
# Polynomial Predictions of personal ELEVATION threshold:  [37.94720258] . Ground truth individual optimal threshold NDH:  44.0
# AUC: 0.662944155222806
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 66.7680608365019%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6367709127771751
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 62.433460076045634%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S012
# Polynomial Predictions of personal COUNT threshold:  [75.64778038] . Ground truth individual optimal threshold NDH:  75.0
# Polynomial Predictions of personal ELEVATION threshold:  [52.38700328] . Ground truth individual optimal threshold NDH:  53.0
# AUC: 0.6650217781396489
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 73.45430107526882%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.47953408219567917
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 53.09139784946236%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S014
# Polynomial Predictions of personal COUNT threshold:  [72.27584239] . Ground truth individual optimal threshold NDH:  80.0
# Polynomial Predictions of personal ELEVATION threshold:  [54.14041103] . Ground truth individual optimal threshold NDH:  50.4
# AUC: 0.631216564747054
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 64.78260869565217%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.5014581643533497
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 50.17391304347826%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S015
# Polynomial Predictions of personal COUNT threshold:  [29.5279691] . Ground truth individual optimal threshold NDH:  58.4
# Polynomial Predictions of personal ELEVATION threshold:  [20.34298475] . Ground truth individual optimal threshold NDH:  31.2
# AUC: 0.5620938510270058
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 49.47916666666667%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.5841633195093012
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 44.70486111111111%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S016
# Polynomial Predictions of personal COUNT threshold:  [51.93580675] . Ground truth individual optimal threshold NDH:  9.8
# Polynomial Predictions of personal ELEVATION threshold:  [32.35691911] . Ground truth individual optimal threshold NDH:  20.0
# AUC: 0.6190349240202612
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 51.19910764082544%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6261663556384964
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 53.26268823201339%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S018
# Polynomial Predictions of personal COUNT threshold:  [66.36761722] . Ground truth individual optimal threshold NDH:  95.8
# Polynomial Predictions of personal ELEVATION threshold:  [20.12462307] . Ground truth individual optimal threshold NDH:  30.6
# AUC: 0.6322416699924254
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 55.700934579439256%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6351859845739092
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 37.05607476635514%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]

# %%
LOOCV_test.plot_LOOCV_YoudenIndex()
LOOCV_test.plot_LOOCV_AUC()
LOOCV_test.plot_LOOCV_Accuracy()

# %%
LOOCV_test.plot_LOOCV_Accuracy_perTask()
