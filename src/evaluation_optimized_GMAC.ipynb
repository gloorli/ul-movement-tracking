# %% [markdown]
# # LOOCV classification performance evaluation
# Notebook to evaluate the tracking performance of functional arm movements using GMAC thresholds derived from the optimized threshold model in comparison with conventional GMAC thresholds.
# Tracking performance is evaluated over all and per task.

# %%
from functions.classification_performance_LOOCV import *
from utilities import *
# Out:
# /Users/linus/Code/imu_processing/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
initial_path = '../data/CreateStudy'
s_json_files = get_json_paths(initial_path, 'S')

# %%
LOOCV_test = LOOCV_performance(s_json_files)

# %%
LOOCV_test.LOOCV_complete()
# Out:
# Validation on participant  S001
# Linear Predictions of personal COUNT threshold:  [2.00971118] . Ground truth individual optimal threshold NDH:  5.0
# Polynomial Predictions of personal ELEVATION threshold:  [50.50953205] . Ground truth individual optimal threshold NDH:  61.0
# Validation on participant  S001
# Linear Predictions of personal COUNT threshold:  [2.02402679] . Ground truth individual optimal threshold NDH:  5.0
# Polynomial Predictions of personal ELEVATION threshold:  [49.394484] . Ground truth individual optimal threshold NDH:  61.0
# AUC: 0.773365316275764
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 87.97232570516232%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.47921108742004265
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 95.68919638105375%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.7749644633972992
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 88.29164449175093%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6264214641080312
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 91.85737094199042%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.6296197583511016
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 92.49600851516763%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.6155185424347317
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 52.29982964224872%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7812403796337316
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 81.60136286201022%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S008
# Linear Predictions of personal COUNT threshold:  [3.12818346] . Ground truth individual optimal threshold NDH:  1.0
# Polynomial Predictions of personal ELEVATION threshold:  [44.74453298] . Ground truth individual optimal threshold NDH:  36.8
# Validation on participant  S008
# Linear Predictions of personal COUNT threshold:  [3.14447797] . Ground truth individual optimal threshold NDH:  1.0
# Polynomial Predictions of personal ELEVATION threshold:  [44.91658842] . Ground truth individual optimal threshold NDH:  36.8
# AUC: 0.709801640070922
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.63294356888663%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7423149379432623
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 69.95424504321302%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7095412234042553
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.5821047280122%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7393727836879431
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.32791052364007%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7414561170212766
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.73462125063548%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6705256011719727
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 63.55624675997926%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7682942080251545
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 84.49974079834111%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S009
# Linear Predictions of personal COUNT threshold:  [1.37446809] . Ground truth individual optimal threshold NDH:  0.4
# Polynomial Predictions of personal ELEVATION threshold:  [42.09055491] . Ground truth individual optimal threshold NDH:  47.0
# Validation on participant  S009
# Linear Predictions of personal COUNT threshold:  [1.40756501] . Ground truth individual optimal threshold NDH:  0.4
# Polynomial Predictions of personal ELEVATION threshold:  [39.66955303] . Ground truth individual optimal threshold NDH:  47.0
# AUC: 0.7192773485696932
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.75494672754947%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6923321501110458
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 67.04718417047184%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7043407490366547
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 70.39573820395738%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7120214118942314
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 71.91780821917808%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7100994666008618
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 71.3089802130898%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7672043857860492
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 76.03930461073318%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7900091756724191
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 80.27210884353741%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S012
# Linear Predictions of personal COUNT threshold:  [1.28235736] . Ground truth individual optimal threshold NDH:  0.0
# Polynomial Predictions of personal ELEVATION threshold:  [52.62224138] . Ground truth individual optimal threshold NDH:  52.2
# Validation on participant  S012
# Linear Predictions of personal COUNT threshold:  [1.32240991] . Ground truth individual optimal threshold NDH:  0.0
# Polynomial Predictions of personal ELEVATION threshold:  [52.07242629] . Ground truth individual optimal threshold NDH:  52.2
# AUC: 0.7057665215163935
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 75.47043010752688%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6081903176229508
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 60.416666666666664%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.703157018442623
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 75.06720430107528%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6823290215163935
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 69.95967741935483%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6817686987704918
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 69.8252688172043%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.693455757231991
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 69.73415132924336%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7431766277577097
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 74.43762781186093%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S014
# Linear Predictions of personal COUNT threshold:  [1.28235736] . Ground truth individual optimal threshold NDH:  0.0
# Polynomial Predictions of personal ELEVATION threshold:  [53.77077511] . Ground truth individual optimal threshold NDH:  50.4
# Validation on participant  S014
# Linear Predictions of personal COUNT threshold:  [1.32240991] . Ground truth individual optimal threshold NDH:  0.0
# Polynomial Predictions of personal ELEVATION threshold:  [49.13728455] . Ground truth individual optimal threshold NDH:  50.4
# AUC: 0.7148187292314534
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.0%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6426896238741964
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 62.52173913043478%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7215438549468355
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.0%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6755918750247472
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 66.26086956521739%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6701200958817742
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.65217391304347%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6772058499625566
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 65.46888694127958%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7438879344522268
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 73.79491673970202%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S015
# Linear Predictions of personal COUNT threshold:  [0.95710247] . Ground truth individual optimal threshold NDH:  7.2
# Polynomial Predictions of personal ELEVATION threshold:  [33.72966486] . Ground truth individual optimal threshold NDH:  30.6
# Validation on participant  S015
# Linear Predictions of personal COUNT threshold:  [0.95710247] . Ground truth individual optimal threshold NDH:  7.2
# Polynomial Predictions of personal ELEVATION threshold:  [32.80695272] . Ground truth individual optimal threshold NDH:  30.6
# AUC: 0.737116115401533
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 66.34865568083261%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7413794968308564
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 68.25672159583695%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.737433390298599
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 66.86903729401561%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7229000367750449
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 62.44579358196011%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7251371853390154
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 62.87944492627927%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6903616274176021
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 68.28451882845188%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.8026910054837716
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 84.76987447698745%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S016
# Linear Predictions of personal COUNT threshold:  [1.38099747] . Ground truth individual optimal threshold NDH:  1.8
# Polynomial Predictions of personal ELEVATION threshold:  [36.49882906] . Ground truth individual optimal threshold NDH:  36.0
# Validation on participant  S016
# Linear Predictions of personal COUNT threshold:  [1.40918561] . Ground truth individual optimal threshold NDH:  1.8
# Polynomial Predictions of personal ELEVATION threshold:  [35.69505374] . Ground truth individual optimal threshold NDH:  36.0
# AUC: 0.7248418970723489
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 71.93080357142857%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7238428167959434
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.32142857142857%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7265612918453888
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.20982142857143%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7062785378836591
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 67.07589285714286%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7082380374889105
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 67.578125%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.5364852022807494
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 55.15320334261838%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7114444746130872
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 78.27298050139275%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S018
# Linear Predictions of personal COUNT threshold:  [2.48124068] . Ground truth individual optimal threshold NDH:  1.4
# Polynomial Predictions of personal ELEVATION threshold:  [34.8933465] . Ground truth individual optimal threshold NDH:  34.4
# Validation on participant  S018
# Linear Predictions of personal COUNT threshold:  [2.49972517] . Ground truth individual optimal threshold NDH:  1.4
# Polynomial Predictions of personal ELEVATION threshold:  [35.13291021] . Ground truth individual optimal threshold NDH:  34.4
# AUC: 0.7959056516179477
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 74.7196261682243%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7982431849094715
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 76.77570093457943%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.8041399587877406
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 74.7196261682243%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7984590198649607
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 65.60747663551402%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.8042254782984062
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 66.72897196261682%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.498498464338528
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 49.71153846153846%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6235809350472075
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 72.6923076923077%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S019
# Linear Predictions of personal COUNT threshold:  [2.88436364] . Ground truth individual optimal threshold NDH:  1.0
# Polynomial Predictions of personal ELEVATION threshold:  [39.50817396] . Ground truth individual optimal threshold NDH:  38.8
# Validation on participant  S019
# Linear Predictions of personal COUNT threshold:  [2.90142149] . Ground truth individual optimal threshold NDH:  1.0
# Polynomial Predictions of personal ELEVATION threshold:  [39.74478079] . Ground truth individual optimal threshold NDH:  38.8
# AUC: 0.7672417834872708
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 79.13816689466483%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.6925828683951427
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 82.42134062927497%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7657977401659712
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 78.86456908344734%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7607389000890806
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 76.74418604651163%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7654320408833044
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 77.63337893296853%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.5783358997637547
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 57.15292459478506%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7171965049731904
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 78.78787878787878%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S020
# Linear Predictions of personal COUNT threshold:  [2.39662513] . Ground truth individual optimal threshold NDH:  1.2
# Polynomial Predictions of personal ELEVATION threshold:  [31.83045328] . Ground truth individual optimal threshold NDH:  39.0
# Validation on participant  S020
# Linear Predictions of personal COUNT threshold:  [2.41574425] . Ground truth individual optimal threshold NDH:  1.2
# Polynomial Predictions of personal ELEVATION threshold:  [32.02940633] . Ground truth individual optimal threshold NDH:  39.0
# AUC: 0.7664452877925364
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 80.40170419963482%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7438330170777989
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 80.52343274497869%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7722960151802656
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 80.03651856360317%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.8219481340923467
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 68.71576384662204%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.814674256799494
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 70.29823493609251%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.5704726005935156
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 55.48667079975201%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.7060466702302177
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 75.077495350279%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]

# %%
LOOCV_test.plot_LOOCV_YoudenIndex()
LOOCV_test.plot_LOOCV_AUC()
LOOCV_test.plot_LOOCV_Accuracy()
LOOCV_test.plot_LOOCV_F1()
# Out:
# The data is normally distributed.
# There is a significant ANOVA difference between the groups.
# Paired t-test optimal vs conventional: 0.09620109071009876
# Paired t-test optimal vs mean: 0.3424034618771709
# Paired t-test conventional vs mean: 0.04965633742748458
# Paired t-test mean vs conventional DH: 6.895379156262534e-05
# Wilcoxon signed-rank test optimal vs conventional: 0.10546875
# Wilcoxon signed-rank test optimal vs mean: 0.322265625
# Wilcoxon signed-rank test conventional vs mean: 0.064453125
# Wilcoxon signed-rank test mean vs conventional DH: 0.001953125
# The data is normally distributed.
# There is a significant ANOVA difference between the groups.
# Paired t-test optimal vs conventional: 0.09620109071009858
# Paired t-test optimal vs mean: 0.34240346187717147
# Paired t-test conventional vs mean: 0.049656337427484265
# Paired t-test mean vs conventional DH: 6.89537915626259e-05
# Wilcoxon signed-rank test optimal vs conventional: 0.10546875
# Wilcoxon signed-rank test optimal vs mean: 0.322265625
# Wilcoxon signed-rank test conventional vs mean: 0.064453125
# Wilcoxon signed-rank test mean vs conventional DH: 0.001953125
# The data is not normally distributed.
# There is a significant ANOVA difference between the groups.
# Paired t-test optimal vs conventional: 0.6461912204961964
# Paired t-test optimal vs mean: 0.01867151824477016
# Paired t-test conventional vs mean: 0.204100085646789
# Paired t-test mean vs conventional DH: 0.000134965507142136
# Wilcoxon signed-rank test optimal vs conventional: 0.921875
# Wilcoxon signed-rank test optimal vs mean: 0.013671875
# Wilcoxon signed-rank test conventional vs mean: 0.16015625
# Wilcoxon signed-rank test mean vs conventional DH: 0.001953125
# The data is normally distributed.
# There is a significant ANOVA difference between the groups.
# Paired t-test optimal vs conventional: 0.07547401223840874
# Paired t-test optimal vs mean: 0.029934138797090268
# Paired t-test conventional vs mean: 0.3052145135178108
# Paired t-test mean vs conventional DH: 3.129073395570142e-05
# Wilcoxon signed-rank test optimal vs conventional: 0.10546875
# Wilcoxon signed-rank test optimal vs mean: 0.005859375
# Wilcoxon signed-rank test conventional vs mean: 0.76953125
# Wilcoxon signed-rank test mean vs conventional DH: 0.001953125

# %%
LOOCV_test.plot_LOOCV_Accuracy_perTask()

# %%
LOOCV_test.spearman_correlation_classification_impairment()
LOOCV_test.plot_FMA_scatter()
# Out:
# {'optimal_YI': SignificanceResult(statistic=-0.601826488243264, pvalue=0.06564599213625302), 'conventional_YI': SignificanceResult(statistic=-0.26747843921922837, pvalue=0.4549860079540271), 'optimal_accuracy': SignificanceResult(statistic=-0.24316221747202585, pvalue=0.49843371099777956), 'conventional_accuracy': SignificanceResult(statistic=-0.8389096502784892, pvalue=0.0024139883688156084)}
