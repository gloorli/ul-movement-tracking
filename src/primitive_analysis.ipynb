# %% [markdown]
# # Analyse distribution of functional primitives

# %%
from functions.primitive_analysis import *

# %%
primitives = PrimitiveDistribution()
primitives.count_primitives_LWRW()
primitives.count_primitives_NDHDH()
primitives.plot_primitive_distribution('NDH')
primitives.plot_primitive_distribution('DH')

# %% [markdown]
# ### Average percentage of functional movements per recording

# %%
percentages_ndh, percentages_dh = calculate_percentage_of_functional()
print('Average percentage of functional movements NDH: {:.2f}'.format(np.mean(percentages_ndh)), '%', 'std: {:.2f}'.format(np.std(percentages_ndh)))
print('Average percentage of functional movements DH: {:.2f}'.format(np.mean(percentages_dh)), '%', 'std: {:.2f}'.format(np.std(percentages_dh)))
# Out:
# Average percentage of functional movements NDH: 24.03 % std: 24.66
# Average percentage of functional movements DH: 66.06 % std: 9.42
