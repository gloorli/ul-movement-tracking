# %% [markdown]
# # Classification performance evaluation
# Notebook to evaluate the detection performance of functional arm movements using GMAC thresholds derived from the regression models in comparison with conventional GMAC thresholds.

# %% [markdown]
# ## LOOCV

# %%
from functions.LOOCV import *
from utilities import *
# Out:
# /Users/linus/Code/imu_processing/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
initial_path = '../data/CreateStudy'
s_json_files = get_json_paths(initial_path, 'S')

# %%
LOOCV_test = LOOCV_performance(s_json_files)

# %%
LOOCV_test.LOOCV_complete(perTask=False)
# Out:
# AUC: 0.9424307036247335
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 88.50452368281%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S001  NDH
# Linear Predictions of personal COUNT threshold:  [1.48514023] . Ground truth individual threshold NDH:  5
# Polynomial Predictions of personal ELEVATION threshold:  [51.67742408] . Ground truth individual threshold NDH:  64
# AUC: 0.7640369580668087
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 86.10963278339541%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.47921108742004265
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 95.68919638105375%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.6264214641080312
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 91.85737094199042%
# ...

# %%
LOOCV_test.plot_LOOCV_YoudenIndex()
LOOCV_test.plot_LOOCV_AUC(significnce_brackets='stars')
LOOCV_test.plot_LOOCV_Accuracy()
LOOCV_test.plot_LOOCV_F1()
# Out:
# The data is normally distributed.
# There is a significant ANOVA difference between the groups.
# Paired t-test personalized vs conventional: 0.07616724530437677
# Paired t-test personalized vs mean: 0.38190358573460237
# Paired t-test conventional vs mean: 0.03232442293900503
# Paired t-test mean vs conventional DH: 5.643735647146907e-05
# Paired t-test personalized vs conventional DH: 0.00018460833618924485
# Paired t-test personalized vs mean DH: 0.29626464035857075
# Wilcoxon signed-rank test personalized vs conventional: 0.037109375
# Wilcoxon signed-rank test personalized vs mean: 0.4921875
# Wilcoxon signed-rank test conventional vs mean: 0.048828125
# Wilcoxon signed-rank test mean vs conventional DH: 0.001953125
# Wilcoxon signed-rank test personalized vs conventional DH: 0.001953125
# Wilcoxon signed-rank test personalized vs mean DH: 0.845703125
# The data is normally distributed.
# There is a significant ANOVA difference between the groups.
# ...

# %% [markdown]
# ## Conventional vs individual thresholds

# %%
from functions.plotEvaluation import *

# %%
Evaluation = PlotEvaluation(s_json_files)

# %%
Evaluation.LOOCV_complete(perTask=False)
# Out:
# AUC: 0.9424307036247335
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 88.50452368281%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# Validation on participant  S001  NDH
# Linear Predictions of personal COUNT threshold:  [1.48514023] . Ground truth individual threshold NDH:  5
# Polynomial Predictions of personal ELEVATION threshold:  [51.67742408] . Ground truth individual threshold NDH:  64
# AUC: 0.7640369580668087
# AUC is clinically useful (≥0.75) according to [Fan et al., 2006]
# Accuracy: 86.10963278339541%
# Accuracy is not clinically useful (<90%) according to [Lang et al., 2020]
# AUC: 0.47921108742004265
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 95.68919638105375%
# Accuracy is clinically useful (≥90%) according to [Lang et al., 2020]
# AUC: 0.6264214641080312
# AUC is not clinically useful (<0.75) according to [Fan et al., 2006]
# Accuracy: 91.85737094199042%
# ...

# %%
Evaluation.plot_YI()
Evaluation.plot_AUC(significnce_brackets='stars')
Evaluation.plot_Accuracy()
Evaluation.plot_F1()
# Out:
# The data is normally distributed.
# Paired t-test individual vs conventional: 0.0475077974135648
# Paired t-test individual vs conventional DH: 2.7457099255056792e-06
# Wilcoxon signed-rank test individual vs conventional: 0.001953125
# Wilcoxon signed-rank test individual vs conventional DH: 0.001953125
# Individual GMAC threshold affected Youden Index: 0.57, standard deviation: 0.13
# Conventional GMAC threshold affected Youden Index: 0.37, standard deviation: 0.17
# Individual GMAC threshold unaffected Youden Index: 0.52, standard deviation: 0.10
# Conventional GMAC threshold unaffected Youden Index: 0.26, standard deviation: 0.16
# The data is normally distributed.
# Paired t-test individual vs conventional: 0.04750779741356472
# Paired t-test individual vs conventional DH: 2.745709925505704e-06
# Wilcoxon signed-rank test individual vs conventional: 0.001953125
# Wilcoxon signed-rank test individual vs conventional DH: 0.001953125
# ...

# %% [markdown]
# ### Performance per subject

# %%
Evaluation.AUC_performance_per_subject(side='NDH')
Evaluation.AUC_performance_per_subject(side='DH')
