# %%
import os
import pandas as pd
from activity_count_function import *
from group_analysis_ac_functions import *
from individual_analysis_ac_functions import *
from utilities import get_statistics
# Out:
# C:\Users\Pierre-Louis\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Pierre-Louis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# C:\Users\Pierre-Louis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# PATH # 

initial_path = '../CreateStudy'

# Constant # 
threshold_labels = ['CT', 'OT']
side_labels = ['ndh', 'DH', 'bilateral']
metric_labels = ['Sensitivity', 'Specificity', 'Accuracy']

# Files to fetch for each participants 
csv_file_names = ['optimal_threshold_AC.csv', 'optimal_threshold_GM.csv',
                  'evaluation_metrics_AC.csv', 'evaluation_metrics_GM.csv']

conventional_functional_space = 30
conventional_threshold_unilateral = 2 # Bailey and Lang, 2013
conventional_threshold_bilateral = 0 # Bailey and Lang, 2013

# %%
# Analysis across individuals #

# %%
# Get the  csv file paths for each participant 
csv_files_dict = find_specific_csv_files(initial_path, csv_file_names)

optimal_threshold_AC_path =  csv_files_dict['optimal_threshold_AC.csv']
optimal_threshold_GM_path = csv_files_dict['optimal_threshold_GM.csv']
evaluation_metrics_AC_path = csv_files_dict['evaluation_metrics_AC.csv']
evaluation_metrics_GM_path = csv_files_dict['evaluation_metrics_GM.csv']

# Get the optimal thresholds from the csv file paths 
group_optimal_threshold_AC = extract_data_from_csv(optimal_threshold_AC_path)
group_optimal_threshold_GM = extract_data_from_csv(optimal_threshold_GM_path)

# Split ndh and dh 
group_optimal_threshold_AC_ndh, group_optimal_threshold_AC_dh = group_optimal_threshold_AC
group_optimal_threshold_GM_ndh, group_optimal_threshold_GM_dh = group_optimal_threshold_GM

# Get the evaluation metrics for each participant 
group_evaluation_metrics_AC = regroup_field_data_metrics(evaluation_metrics_AC_path)
group_evaluation_metrics_GM = regroup_field_data_metrics(evaluation_metrics_GM_path)

# %%
optimal_threshold_AC_path
# Out:
# ['../CreateStudy\\H001\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H002\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H003\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H004\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H005\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H006\\optimal_threshold_AC.csv',
#  '../CreateStudy\\H007\\optimal_threshold_AC.csv']

# %%
plot_side_by_side_boxplots(group_optimal_threshold_AC_ndh, group_optimal_threshold_AC_dh, conventional_threshold_unilateral, 'Distribution of the AC optimal thresholds accross individuals')

# %%
plot_side_by_side_boxplots(group_optimal_threshold_GM_ndh, group_optimal_threshold_GM_dh, conventional_functional_space, 'Distribution of the optimal functional spaces accross individuals')

# %%
metric_names_to_plot = ['Sensitivity', 'Specificity', 'Accuracy', 'Youden Index']
plot_side_metrics(group_evaluation_metrics_AC, metric_names_to_plot)
# Sensitivity measures the ability of a model to correctly identify positive instances
# (e.g., the presence of a certain condition or event).
# Specificity measures the ability of a model to correctly identify negative instances
#(e.g., the absence of a certain condition or event).
# Accuracy measures the overall correctness of the model's predictions, considering both true positives and true negatives.
# Youden Index is often used when the model's performance needs to balance sensitivity and specificity,
#and there is a need to optimize the trade-off between true positive rate and false positive rate.

# %%
# Group Analysis #

# %%
# Constant # 
group_csv_file_names = ['count_brond_ndh.csv', 'count_brond_dh.csv', 'GT_mask_ndh_1Hz.csv', 'GT_mask_dh_1Hz.csv']

# %%
# Get the  csv files for each participant 
group_csv_files_dict = find_specific_csv_files(initial_path, group_csv_file_names)

count_brond_ndh =  group_csv_files_dict['count_brond_ndh.csv']
count_brond_dh = group_csv_files_dict['count_brond_dh.csv']
GT_mask_ndh_1Hz = group_csv_files_dict['GT_mask_ndh_1Hz.csv']
GT_mask_dh_1Hz = group_csv_files_dict['GT_mask_dh_1Hz.csv']

# %%
count_brond_ndh
# Out:
# ['../CreateStudy\\H001\\count_brond_ndh.csv',
#  '../CreateStudy\\H002\\count_brond_ndh.csv',
#  '../CreateStudy\\H003\\count_brond_ndh.csv',
#  '../CreateStudy\\H004\\count_brond_ndh.csv',
#  '../CreateStudy\\H005\\count_brond_ndh.csv',
#  '../CreateStudy\\H006\\count_brond_ndh.csv',
#  '../CreateStudy\\H007\\count_brond_ndh.csv']

# %%
def resample_AC(AC, original_frequency, desired_frequency):
    # Calculate the time steps of the original and desired frequencies
    original_time_step = 1 / original_frequency
    desired_time_step = 1 / desired_frequency

    # Calculate the time array for the original AC
    original_time_array = np.arange(0, len(AC)) * original_time_step

    # Calculate the time array for the resampled AC
    resampled_time_array = np.arange(0, len(AC) - 1, original_frequency / desired_frequency) * original_time_step

    # Create a CubicSpline object to perform interpolation
    cs = CubicSpline(original_time_array, AC)

    # Perform cubic spline interpolation on the resampled time array
    resampled_AC = cs(resampled_time_array)

    # Set negative values to zero
    resampled_AC[resampled_AC < 0] = 0

    return np.array(resampled_AC)

# %%
import numpy as np
from scipy.interpolate import CubicSpline

def resample_binary_mask(mask, original_frequency, desired_frequency):
    # Calculate the time steps of the original and desired frequencies
    original_time_step = 1 / original_frequency
    desired_time_step = 1 / desired_frequency

    # Calculate the time array for the original mask
    original_time_array = np.arange(0, len(mask)) * original_time_step

    # Calculate the time array for the resampled mask
    resampled_time_array = np.arange(0, len(mask) - 1, original_frequency / desired_frequency) * original_time_step

    # Create a CubicSpline object to perform interpolation
    cs = CubicSpline(original_time_array, mask)

    # Perform cubic spline interpolation on the resampled time array
    resampled_mask = cs(resampled_time_array)

    # Apply thresholding to make values binary (0 or 1)
    resampled_mask = np.where(resampled_mask >= 0.5, 1, 0)

    return np.array(resampled_mask, dtype=int)

# %%
def resample_mask(mask, original_frequency, desired_frequency):
    if desired_frequency > original_frequency:
        # Upsample the mask using nearest neighbor interpolation
        zoom_factor = desired_frequency / original_frequency
        resampled_mask = zoom(mask, zoom_factor, order=0)
    else:
        # Downsample the mask using scipy.signal.resample
        num_data_points = int(len(mask) * desired_frequency / original_frequency)
        resampled_mask = np.round(resample(mask, num_data_points)).astype(int)
        
    return resampled_mask

def plot_resampled_arrays(original_mask, original_frequency, resampled_mask, desired_frequency):
    time_original = np.arange(len(original_mask)) / original_frequency
    time_resampled = np.arange(len(resampled_mask)) / desired_frequency

    plt.figure(figsize=(10, 6))

    plt.plot(time_original, original_mask, label=f'Original ({original_frequency}Hz)')
    plt.plot(time_resampled, resampled_mask, label=f'Resampled ({desired_frequency}Hz)', linestyle='--')

    plt.xlabel('Time (seconds)')
    plt.ylabel('Mask Value (0 or 1)')
    plt.title('Original and Resampled Mask')
    plt.legend()
    plt.grid(True)
    plt.show()


def get_group_dataset_from_csv(csv_files, mask=True):
    """
    Resamples data from CSV files to match the smallest length among the arrays.

    Args:
        csv_files (list): List of CSV file paths.
        mask (bool): Boolean flag indicating whether the data is a mask.

    Returns:
        np.ndarray: NumPy array of resampled data arrays.
    """
    all_data = []
    min_length = float('inf')
    elements_removed = []  # List to store the number of elements removed for each array
    resampled_data = []

    for csv_file in csv_files:
        # Read the CSV file and extract the data
        df = pd.read_csv(csv_file)
        data = df.iloc[:, 0].values
        # Update the minimum length
        min_length = min(min_length, len(data))
        all_data.append(data)
        print(data.shape)

    for data in all_data:
        # First get the original_frequency and desired_frequency given by the minimum array size to achieve
        original_frequency = len(data)
        desired_frequency = min_length
        
        
        if mask: 
            # Downsample the binary mask using the resample_mask function
            # Then downsample the mask 
            if desired_frequency != desired_frequency:
                resampled_values = resample_binary_mask(data, original_frequency, desired_frequency)
            else: 
                resampled_values = data

            # Plot the data before and after resampling 
            plot_resampled_arrays(data, original_frequency, resampled_values, desired_frequency)

            # Save the new resampled values inside the resampled_data array 
            resampled_data.append(resampled_values)

            # Print the number of elements removed by this resampling operation 
            num_removed = len(data) - len(resampled_values)
            elements_removed.append(num_removed)
            
        else: 
            # Case of AC resampling
            if desired_frequency != desired_frequency:
                resampled_values = resample_AC(data, original_frequency, desired_frequency)
            else: 
                resampled_values = data
            # Plot the data before and after resampling 
            plot_resampled_arrays(data, original_frequency, resampled_values, desired_frequency)
            
            # Save the new resampled values inside the resampled_data array 
            resampled_data.append(resampled_values)
            
            # Print the number of elements removed by this resampling operation 
            num_removed = len(data) - len(resampled_values)
            elements_removed.append(num_removed)
        
    group_data = np.concatenate(resampled_data, axis=0)
    
    print(group_data)
    # Print the number of elements removed for each array
    for idx, num_removed in enumerate(elements_removed, start=1):
        print(f"Elements removed in array {idx}: {num_removed}")

    return group_data

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

def generate_sample_data(num_points, frequency, amplitude):
    # Generate sample data with sine wave pattern
    time = np.arange(num_points) / frequency
    data = amplitude * np.sin(2 * np.pi * time)
    return data

def plot_resampled_data(original_data, original_frequency, resampled_data, desired_frequency):
    time_original = np.arange(len(original_data)) / original_frequency
    time_resampled = np.arange(len(resampled_data)) / desired_frequency

    plt.figure(figsize=(10, 6))

    plt.plot(time_original, original_data, label='Original Data', marker='o', linestyle='--')
    plt.plot(time_resampled, resampled_data, label='Resampled Data', marker='x', linestyle='-')

    plt.xlabel('Time (seconds)')
    plt.ylabel('AC Data')
    plt.title('Original and Resampled AC Data')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Compute the group dataset, downsampling to the smallest participant dataset
# group_count_brond_ndh = get_group_dataset_from_csv(count_brond_ndh, mask=False)
# group_count_brond_dh = get_group_dataset_from_csv(count_brond_dh, mask=False)
group_GT_mask_ndh_1Hz = get_group_dataset_from_csv(GT_mask_ndh_1Hz, mask=True)
group_GT_mask_dh_1Hz = get_group_dataset_from_csv(GT_mask_dh_1Hz, mask=True)
# Out:
# (965,)
# (821,)
# (831,)
# (855,)
# (707,)
# (767,)
# (880,)
# [1 1 0 ... 0 1 1]
# Elements removed in array 1: 0
# Elements removed in array 2: 0
# Elements removed in array 3: 0
# Elements removed in array 4: 0
# Elements removed in array 5: 0
# Elements removed in array 6: 0
# Elements removed in array 7: 0
# (965,)
# (821,)
# (831,)
# (855,)
# (707,)
# (767,)
# (880,)
# [0 0 0 ... 0 0 0]
# Elements removed in array 1: 0
# Elements removed in array 2: 0
# Elements removed in array 3: 0
# Elements removed in array 4: 0
# Elements removed in array 5: 0
# Elements removed in array 6: 0
# Elements removed in array 7: 0

# %%
get_statistics(group_count_brond_ndh), get_statistics(group_GT_mask_ndh_1Hz),
# Out:
# ({'mean': 169.49245332507098,
#   'median': 119.81235328629516,
#   'iqr': 261.6945818722233,
#   'range': 1219.3067702592325,
#   'std': 182.97364817294022,
#   'max': 1219.3067702592325,
#   'min': 0.0,
#   'num_elements': 5833},
#  {'mean': 0.5746652935118435,
#   'median': 1.0,
#   'iqr': 1.0,
#   'range': 1,
#   'std': 0.49439366292944154,
#   'max': 1,
#   'min': 0,
#   'num_elements': 5826})

# %%
# Perform ROC for the entire group using k fold cross validation

# %%
# Splitting the data for the ND wrist
X_ndh = group_count_brond_ndh
y_ndh = group_GT_mask_ndh_1Hz

# %%
X_ndh
# Out:
# array([524.96571317, 178.24727709, 119.48793083, ...,          nan,
#                 nan,          nan])

# %%
# Perform k-fold cross-validation for the ND wrist data
# Optimal: Return average optimal AC threshold and average evaluation metrics 
eval_metrics_opt_ndh, opt_threshold_ndh = k_fold_cross_validation(X_ndh, y_ndh, optimal=True)

# Conventional: Return conventional AC threshold and average evaluation metrics 
eval_metrics_conv_ndh, conv_threshold_ndh = k_fold_cross_validation(X_ndh, y_ndh, optimal=False)
# Out:
# Iteration 1/5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 7>()
#       3 y_ndh = group_GT_mask_ndh_1Hz
#       5 # Perform k-fold cross-validation for the ND wrist data
#       6 # Optimal: Return average optimal AC threshold and average evaluation metrics
# ----> 7 eval_metrics_opt_ndh, opt_threshold_ndh = k_fold_cross_validation(X_ndh, y_ndh, optimal=True)
#       9 # Conventional: Return conventional AC threshold and average evaluation metrics
#      10 eval_metrics_conv_ndh, conv_threshold_ndh = k_fold_cross_validation(X_ndh, y_ndh, optimal=False)
#
# File ~\Documents\SEC\ZurichMove\individual_analysis_ac_functions.py:732, in k_fold_cross_validation(X, y, k, random_state, optimal)
#     729 print(f"Iteration {idx}/{k}")
#     731 X_train, X_eval = X[train_index], X[test_index]
# --> 732 y_train, y_eval = y[train_index], y[test_index]
# ...

# %%
# Splitting the data for the right wrist
X_dh = group_count_brond_dh
y_dh = group_GT_mask_dh_1Hz

# Perform k-fold cross-validation for the right wrist data
# Optimal: Return average optimal AC threshold and average evaluation metrics 
eval_metrics_opt_dh, opt_threshold_dh = k_fold_cross_validation(X_dh, y_dh, optimal=True)

# Conventional: Return conventional AC threshold and average evaluation metrics 
eval_metrics_conv_dh, conv_threshold_dh = k_fold_cross_validation(X_dh, y_dh, optimal=False)

# %%
eval_metrics_opt_bil = k_fold_cross_validation_bilateral(X_ndh, X_dh, y_ndh, y_dh, opt_threshold_ndh,
                                                         opt_threshold_dh, optimal=True)
eval_metrics_conv_bil = k_fold_cross_validation_bilateral(X_ndh, X_dh, y_ndh, y_dh, opt_threshold_ndh,
                                                          opt_threshold_dh, optimal=False)

# %%
print(opt_threshold_ndh, opt_threshold_dh)

# %%
plot_radar_chart(eval_metrics_conv_ndh, eval_metrics_opt_ndh)

# %%
plot_radar_chart(eval_metrics_conv_dh, eval_metrics_opt_dh)

# %%
plot_radar_chart(eval_metrics_conv_bil, eval_metrics_opt_bil)

# %%
# Create a structure to save all the metrics 
metrics_dictionary = create_metrics_dictionary(eval_metrics_conv_ndh, eval_metrics_conv_dh, eval_metrics_conv_bil, eval_metrics_opt_ndh, eval_metrics_opt_dh, eval_metrics_opt_bil)
metrics_dictionary

# %%
# Save metrics as csv file: evaluation metrics on unseen data 
save_metrics_dictionary_as_csv(metrics_dictionary, initial_path)
# Save optimal AC threhshold for this participant 
save_optimal_threshold(initial_path, optimal_threshold_ndh, optimal_threshold_dh)
